# %%
import scipy as sp
import numpy as np
from scipy.misc import derivative

# %% [markdown]
# ## Уровень 0

# %%
## f(x) = x^5 + 4sin(2x) + cos(3x+3)

def f(x):
    return x**5 + 4*np.sin(2*x) + np.cos(3*x+3)

# %%
derivative(f,1.0,dx=1e-6)
# Out:
# 2.509071801881646

# %%
derivative(f,1.0, n=2, dx=1e-6)
# Out:
# -3.19033688356285

# %%
## Проверим, f'(x) = 5x^4 + 8cos(2x) - 3sin(3x + 3) или 5 + 8cos(2) - 3sin(6)

# %%
5 + 8*np.cos(2) - 3*np.sin(6)
# Out:
# 2.5090718022196383

# %%
20 - 16*np.sin(2) - 9*np.cos(6)
# Out:
# -3.1902914090642014

# %% [markdown]
# ## Уровень 1

# %%
#Постройте график первой и второй производной функции:
#f(x) = sin^5(2x+1)$
#На отрезке [-5; 5].

# %%
def d(y):
    return pow(np.sin(2*y+1),5)
y = np.linspace(-5,5)
dy = d(y)
d1y = [derivative(d, yy, dx = 1e-6, n = 1) for yy in y]
d2y = [derivative(d, yy, dx = 1e-6, n = 2) for yy in y]

plt.plot(y, dy, label = 'function')
plt.plot(y, d1y, label = 'derivative')
plt.plot(y, d2y, label = '2nd derivative')
plt.legend()
plt.show()
